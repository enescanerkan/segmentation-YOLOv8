# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd
# Out:
# /root

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !unzip /content/drive/MyDrive/data.zip -d data
# Out:
# Archive:  /content/drive/MyDrive/data.zip
#    creating: data/data/
#    creating: data/data/train/
#    creating: data/data/train/images/
#   inflating: data/data/train/images/1.jpeg
#   inflating: data/data/train/images/10.jpeg
#   inflating: data/data/train/images/101.jpeg
#   inflating: data/data/train/images/102.jpeg
#   inflating: data/data/train/images/103.jpeg
#   inflating: data/data/train/images/104.jpeg
#   inflating: data/data/train/images/105.jpeg
#   inflating: data/data/train/images/106.jpeg
#   inflating: data/data/train/images/107.jpeg
#   inflating: data/data/train/images/109.jpeg
#   inflating: data/data/train/images/11.jpeg
#   inflating: data/data/train/images/110.jpeg
#   inflating: data/data/train/images/113.jpeg
#   inflating: data/data/train/images/114.jpeg
#   inflating: data/data/train/images/116.jpeg
#   inflating: data/data/train/images/117.jpeg
#   inflating: data/data/train/images/118.jpeg
#   inflating: data/data/train/images/119.jpeg
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 877.1/877.1 kB 22.2 MB/s eta 0:00:00
# ...

# %%
# !yolo segment train data=/content/drive/MyDrive/data.yaml model=yolov8m-seg.pt epochs=200 imgsz=640 workers=8 batch=8 device=0 name=blocks_segmentation
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !unzip /content/drive/MyDrive/test.zip -d test
# Out:
# Archive:  /content/drive/MyDrive/test.zip
#    creating: test/test/
#   inflating: test/test/1.jpeg
#   inflating: test/test/1111.jpeg
#   inflating: test/test/1313.jpeg
#   inflating: test/test/162.jpeg
#   inflating: test/test/17.jpg
#   inflating: test/test/22.jpeg
#   inflating: test/test/25.jpeg
#   inflating: test/test/31.jpeg
#   inflating: test/test/323.jpeg
#   inflating: test/test/36.jpg
#   inflating: test/test/4.jpg
#   inflating: test/test/41.jpeg
#   inflating: test/test/5.jpg
#   inflating: test/test/555.jpeg
#   inflating: test/test/6.jpeg
#   inflating: test/test/7.jpeg
#   inflating: test/test/77.jpeg
#   inflating: test/test/8.jpeg
#   inflating: test/test/81.jpeg
#   inflating: test/test/876.jpeg

# %%
from ultralytics import YOLO

# Modeli yükleyin
model = YOLO('/content/runs/segment/blocks_segmentation2/weights/best.pt')

# Tahmin yapın
results = model.predict(source='/content/test/test', save=True)
# Out:
# image 1/20 /content/test/test/1.jpeg: 640x384 9 metal_blocks, 71.5ms
# image 2/20 /content/test/test/1111.jpeg: 640x320 1 metal_block, 79.9ms
# image 3/20 /content/test/test/1313.jpeg: 320x640 2 metal_blocks, 82.1ms
# image 4/20 /content/test/test/162.jpeg: 640x608 6 metal_blocks, 81.4ms
# image 5/20 /content/test/test/17.jpg: 640x640 3 metal_blocks, 46.9ms
# image 6/20 /content/test/test/22.jpeg: 640x320 (no detections), 25.6ms
# image 7/20 /content/test/test/25.jpeg: 320x640 3 metal_blocks, 24.5ms
# image 8/20 /content/test/test/31.jpeg: 320x640 (no detections), 23.4ms
# image 9/20 /content/test/test/323.jpeg: 576x640 7 metal_blocks, 77.2ms
# image 10/20 /content/test/test/36.jpg: 640x640 3 metal_blocks, 40.4ms
# image 11/20 /content/test/test/4.jpg: 640x640 7 metal_blocks, 38.8ms
# image 12/20 /content/test/test/41.jpeg: 320x640 7 metal_blocks, 24.6ms
# image 13/20 /content/test/test/5.jpg: 640x640 6 metal_blocks, 32.7ms
# ...

# %%
# !yolo segment train  model=/content/runs/segment/blocks_segmentation2/weights/last.pt resume=True
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
